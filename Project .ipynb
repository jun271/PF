# %%
import pandas as pd

# %%
df =pd.read_csv("mydata.csv")

# %%
df.sample(2)
# Out:
#     PassengerId  Pclass                        Name     Sex   Age  SibSp  \
# 87          979       3  Badman, Miss. Emily Louisa  female  18.0      0
# 40          932       3            Karun, Mr. Franz    male  39.0      0
#
#     Parch     Ticket     Fare Cabin Embarked
# 87      0  A/4 31416   8.0500   NaN        S
# 40      1     349256  13.4167   NaN        C

# %%
df.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.shape[1]
# Out:
# 11

# %%
df.size
# Out:
# 1144

# %%
df.shape
# Out:
# (104, 11)

# %%
df.tail(5)
# Out:
#      PassengerId  Pclass                                               Name  \
# 99           991       3                       Nancarrow, Mr. William Henry
# 100          992       1  Stengel, Mrs. Charles Emil Henry (Annie May Mo...
# 101          993       2                                 Weisz, Mr. Leopold
# 102          994       3                                 Foley, Mr. William
# 103          995       3             Johansson Palmquist, Mr. Oskar Leander
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 99     male  33.0      0      0  A./5. 3338   8.0500   NaN        S
# 100  female  43.0      1      0       11778  55.4417  C116        C
# 101    male  27.0      1      0      228414  26.0000   NaN        S
# 102    male   NaN      0      0      365235   7.7500   NaN        Q
# 103    male  26.0      0      0      347070   7.7750   NaN        S

# %%
df[0:5]
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.rename({"Pclass":"Class","SibSp":"Sibsp"}, axis=1)
# Out:
#      PassengerId  Class                                               Name  \
# 0            892      3                                   Kelly, Mr. James
# 1            893      3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894      2                          Myles, Mr. Thomas Francis
# 3            895      3                                   Wirz, Mr. Albert
# 4            896      3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897      3                         Svensson, Mr. Johan Cervin
# 6            898      3                               Connolly, Miss. Kate
# 7            899      2                       Caldwell, Mr. Albert Francis
# 8            900      3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901      3                            Davies, Mr. John Samuel
# 10           902      3                                   Ilieff, Mr. Ylio
# ...

# %%
df.select_dtypes
# Out:
# <bound method DataFrame.select_dtypes of      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %% [markdown]
# **Data Cleaning**

# %%
df.dropna()
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# 34           926       1                           Mock, Mr. Philipp Edmund
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46           938       1                           Chevre, Mr. Paul Romaine
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 50           942       1                           Smith, Mr. Lucien Philip
# 53           945       1                         Fortune, Miss. Ethel Flora
# ...

# %%
df.dropna(inplace=True)

# %%
df.fillna(130, inplace=True)

# %%
df[df["PassengerId"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.isnull()
# Out:
#      PassengerId  Pclass   Name    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 12         False   False  False  False  False  False  False   False  False
# 14         False   False  False  False  False  False  False   False  False
# 24         False   False  False  False  False  False  False   False  False
# 26         False   False  False  False  False  False  False   False  False
# 28         False   False  False  False  False  False  False   False  False
# 34         False   False  False  False  False  False  False   False  False
# 44         False   False  False  False  False  False  False   False  False
# 46         False   False  False  False  False  False  False   False  False
# 48         False   False  False  False  False  False  False   False  False
# 50         False   False  False  False  False  False  False   False  False
# 53         False   False  False  False  False  False  False   False  False
# ...

# %%
df.duplicated()
# Out:
# 12     False
# 14     False
# 24     False
# 26     False
# 28     False
# 34     False
# 44     False
# 46     False
# 48     False
# 50     False
# 53     False
# 57     False
# 59     False
# 64     False
# 68     False
# 69     False
# 73     False
# 74     False
# 75     False
# 77     False
# 81     False
# 92     False
# 96     False
# 100    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# 34           926       1                           Mock, Mr. Philipp Edmund
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46           938       1                           Chevre, Mr. Paul Romaine
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 50           942       1                           Smith, Mr. Lucien Philip
# 53           945       1                         Fortune, Miss. Ethel Flora
# ...

# %%
df["PassengerId"].value_counts()
# Out:
# PassengerId
# 904    1
# 906    1
# 988    1
# 984    1
# 973    1
# 969    1
# 967    1
# 966    1
# 965    1
# 961    1
# 960    1
# 956    1
# 951    1
# 949    1
# 945    1
# 942    1
# 940    1
# 938    1
# 936    1
# 926    1
# 920    1
# 918    1
# 916    1
# 992    1
# Name: count, dtype: int64

# %% [markdown]
# **Data Preprocessing**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 12 to 100
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  24 non-null     int64
#  1   Pclass       24 non-null     int64
#  2   Name         24 non-null     object
#  3   Sex          24 non-null     object
#  4   Age          24 non-null     float64
#  5   SibSp        24 non-null     int64
#  6   Parch        24 non-null     int64
#  7   Ticket       24 non-null     object
#  8   Fare         24 non-null     float64
#  9   Cabin        24 non-null     object
#  10  Embarked     24 non-null     object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#        PassengerId     Pclass        Age      SibSp      Parch        Fare
# count    24.000000  24.000000  24.000000  24.000000  24.000000   24.000000
# mean    948.833333   1.083333  39.250000   0.750000   0.583333  114.417542
# std      25.097491   0.408248  15.819636   0.793999   1.138904   96.750642
# min     904.000000   1.000000  13.000000   0.000000   0.000000    7.650000
# 25%     933.500000   1.000000  27.750000   0.000000   0.000000   46.625000
# 50%     950.000000   1.000000  35.500000   1.000000   0.000000   61.577100
# 75%     966.250000   1.000000  47.250000   1.000000   0.250000  214.069800
# max     992.000000   3.000000  76.000000   3.000000   4.000000  263.000000

# %%
df.describe(include="all").iloc[[0,10]]
# Out:
#        PassengerId  Pclass Name  Sex   Age  SibSp  Parch Ticket   Fare Cabin  \
# count         24.0    24.0   24   24  24.0   24.0   24.0     24   24.0    24
# max          992.0     3.0  NaN  NaN  76.0    3.0    4.0    NaN  263.0   NaN
#
#       Embarked
# count       24
# max        NaN

# %%
df.describe(include="all").loc[["min","max"]]
# Out:
#      PassengerId  Pclass Name  Sex   Age  SibSp  Parch Ticket    Fare Cabin  \
# min        904.0     1.0  NaN  NaN  13.0    0.0    0.0    NaN    7.65   NaN
# max        992.0     3.0  NaN  NaN  76.0    3.0    4.0    NaN  263.00   NaN
#
#     Embarked
# min      NaN
# max      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 12 to 100
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  24 non-null     int64
#  1   Pclass       24 non-null     int64
#  2   Name         24 non-null     object
#  3   Sex          24 non-null     object
#  4   Age          24 non-null     float64
#  5   SibSp        24 non-null     int64
#  6   Parch        24 non-null     int64
#  7   Ticket       24 non-null     object
#  8   Fare         24 non-null     float64
#  9   Cabin        24 non-null     object
#  10  Embarked     24 non-null     object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 2.2+ KB

# %%
b = df[["PassengerId","Fare"]]
b.head(5)
# Out:
#     PassengerId      Fare
# 12          904   82.2667
# 14          906   61.1750
# 24          916  262.3750
# 26          918   61.9792
# 28          920   30.5000

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
df["PassengerId"].isnull()
# Out:
# 12     False
# 14     False
# 24     False
# 26     False
# 28     False
# 34     False
# 44     False
# 46     False
# 48     False
# 50     False
# 53     False
# 57     False
# 59     False
# 64     False
# 68     False
# 69     False
# 73     False
# 74     False
# 75     False
# 77     False
# 81     False
# 92     False
# 96     False
# 100    False
# Name: PassengerId, dtype: bool

# %% [markdown]
# **Data Augmentation**

# %%
df["Fare"].mode()
# Out:
# 0    262.375
# Name: Fare, dtype: float64

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
a = df["Ticket"]
print(a)
# Out:
# 12           21228
# 14     W.E.P. 5734
# 24        PC 17608
# 26          113509
# 28          113054
# 34           13236
# 44           11753
# 46        PC 17594
# 48           11813
# 50           13695
# 53           19950
# 57          348122
# 59        PC 17608
# 64        PC 17608
# 68            2543
# 69           19950
# 73        PC 17562
# 74          113503
# 75          113503
# 77           11770
# 81        PC 17483
# 92      F.C. 12750
# 96           19877
# 100          11778
# Name: Ticket, dtype: object

# %%
df["SibSp"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='SibSp'>

# %%
df["SibSp"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Ticket"].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Cabin"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Cabin'>

# %%
df["Ticket"].max()
# Out:
# 'W.E.P. 5734'

# %%
df["Ticket"].min()
# Out:
# '113054'

# %%
df["Fare"].mode()
# Out:
# 0    262.375
# Name: Fare, dtype: float64

# %%
df["Fare"].sum()
# Out:
# 2746.0209999999997

# %%
df.groupby("Name").describe()
# Out:
#                                                    PassengerId             \
#                                                          count   mean std
# Name
# Abelseth, Mr. Olaus Jorgensen                              1.0  949.0 NaN
# Brady, Mr. John Bertram                                    1.0  920.0 NaN
# Bucknell, Mrs. William Robert (Emma Eliza Ward)            1.0  940.0 NaN
# Cavendish, Mrs. Tyrell William (Julia Florence ...         1.0  988.0 NaN
# Chaffee, Mrs. Herbert Fuller (Carrie Constance ...         1.0  906.0 NaN
# Chaudanson, Miss. Victorine                                1.0  951.0 NaN
# Chevre, Mr. Paul Romaine                                   1.0  938.0 NaN
# Cornell, Mrs. Robert Clifford (Malvina Helen La...         1.0  969.0 NaN
# Davidson, Mrs. Thornton (Orian Hays)                       1.0  984.0 NaN
# Fortune, Miss. Ethel Flora                                 1.0  945.0 NaN
# Fortune, Mrs. Mark (Mary McDougald)                        1.0  961.0 NaN
# ...

# %%
df.fillna(method="bfill")
# Out:
# C:\Users\Al Hafiz Enterprises\AppData\Local\Temp\ipykernel_14568\3896554658.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# 34           926       1                           Mock, Mr. Philipp Edmund
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46           938       1                           Chevre, Mr. Paul Romaine
# ...

# %%
df.fillna(method="ffill")
# Out:
# C:\Users\Al Hafiz Enterprises\AppData\Local\Temp\ipykernel_14568\3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# 34           926       1                           Mock, Mr. Philipp Edmund
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46           938       1                           Chevre, Mr. Paul Romaine
# ...
